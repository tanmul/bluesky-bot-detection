# %%
import sys
sys.path.append('../')

import logging
log = logging.getLogger()
log.setLevel('DEBUG')

# %%
from services.bluesky_ingestion.src.infrastructure.queues import firehose_queue
from services.bluesky_ingestion.src.infrastructure.data import firehose_stream

stream_queue = firehose_queue.FirehoseQueue(maxsize=10)
stream = firehose_stream.BlueskyFirehoseStream(
    "wss://jetstream2.us-east.bsky.network/subscribe?wantedCollections=app.bsky.feed.post",
    stream_queue
)

await stream.start()
# Out:
# Received response: {'did': 'did:plc:n7yi3kpnye4e4iryocbrq6yt', 'time_us': 1774503709883757, 'kind': 'commit', 'commit': {'rev': '3mhwvfoaqvx2g', 'operation': 'create', 'collection': 'app.bsky.feed.post', 'rkey': '3mhwvfpmdvc22', 'record': {'$type': 'app.bsky.feed.post', 'createdAt': '2026-03-26T05:41:51.026Z', 'langs': ['en'], 'text': "Ok, but for real, fuck that three knight elite fight on the third floor of Slay The Spire 2. More often than not, that's the fight that kills me. It's just too much at once and really hard to kill the ones that fuck up your deck quickly enough to not make everything go south real fast."}, 'cid': 'bafyreifmiy2wpnnmfy2qieb6ps57qbe2hfqm2zsjrqgmsstpof6neru4cq'}}
# Received response: {'did': 'did:plc:j4l7csuiwkigczfevuyz4p4g', 'time_us': 1774503709896817, 'kind': 'commit', 'commit': {'rev': '3mhwvfofxyt26', 'operation': 'create', 'collection': 'app.bsky.feed.post', 'rkey': '3mhwvfnjj7s2s', 'record': {'$type': 'app.bsky.feed.post', 'createdAt': '2026-03-26T05:41:48.835Z', 'embed': {'$type': 'app.bsky.embed.images', 'images': [{'alt': '', 'aspectRatio': {'height': 534, 'width': 534}, 'image': {'$type': 'blob', 'ref': {'$link': 'bafkreicycuxqphyqvyneq2yznzvvscgfofij5q3pqdzivqi52ecu3klhli'}, 'mimeType': 'image/jpeg', 'size': 96132}}]}, 'langs': ['fr'], 'reply': {'parent': {'cid': 'bafyreicautidtpaevkxzc43oncoljug6riuhqz2qwr5ytqdwxg6q3qsoau', 'uri': 'at://did:plc:csipjod3mtfy73mcvyja3z5a/app.bsky.feed.post/3mhwpnz72t224'}, 'root': {'cid': 'bafyreiayt2owdyxtahukpipghvcdtozxgijlnvc5r7bmfexl6ez5evjqau', 'uri': 'at://did:plc:j4l7csuiwkigczfevuyz4p4g/app.bsky.feed.post/3mhvi5q45cc2i'}}, 'text': ''}, 'cid': 'bafyreiergzmmvqnnij3ndsjnu4cqtj5wrshglqqczw2fk7ofem5l2xk4ay'}}
# Received response: {'did': 'did:plc:2svnvmqztcdtvlwax4pznq2l', 'time_us': 1774503709899558, 'kind': 'commit', 'commit': {'rev': '3mhwvfodfxj2q', 'operation': 'create', 'collection': 'app.bsky.feed.post', 'rkey': '3mhwvfnxcms25', 'record': {'$type': 'app.bsky.feed.post', 'createdAt': '2026-03-26T05:41:49.288Z', 'langs': ['en'], 'text': 'tes orteils dans ma bouche'}, 'cid': 'bafyreifdxchuxfpurg553oxb6nyyxksrftberljbbotpjvggmlq5d6akby'}}
# Received response: {'did': 'did:plc:q2ya74i3l4ysfohhrgyzd7jf', 'time_us': 1774503709941001, 'kind': 'commit', 'commit': {'rev': '3mhwvfofg2k2t', 'operation': 'delete', 'collection': 'app.bsky.feed.post', 'rkey': '3mhwuy3s7jk2u'}}
# Received response: {'did': 'did:plc:hp63vsxgqr575rq2rgmutzim', 'time_us': 1774503709945549, 'kind': 'commit', 'commit': {'rev': '222223k4byu22', 'operation': 'create', 'collection': 'app.bsky.feed.post', 'rkey': '3mhwvfh5vmym2', 'record': {'$type': 'app.bsky.feed.post', 'bridgyOriginalText': '新しい記事が投稿されました<br /><br />■<br />金持ちを貧乏人...<br /><a href="https://anond.hatelabo.jp/20260326144026">https://anond.hatelabo.jp/20260326144026</a>', 'bridgyOriginalUrl': 'https://jiskey.dev/notes/akalzwr671r20gpe', 'createdAt': '2026-03-26T05:41:36.786Z', 'embed': {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': '金持ちを貧乏人にしたところで、貧乏人が金持ちになるわけではありません！金持ちが貧乏人以下に落ちたら貧乏人が金持ちに繰り上がるんじゃな…', 'thumb': {'$type': 'blob', 'ref': {'$link': 'bafkreifdjqezilprlwrzmu6bmytmsajtdwkowmt7qgz4ijxry4tf2i4mfy'}, 'mimeType': 'image/gif', 'size': 30078}, 'title': '金持ちを貧乏人にしたところで、貧乏人が金持ちになるわけではありません..', 'uri': 'https://anond.hatelabo.jp/20260326144026'}}, 'facets': [{'$type': 'app.bsky.richtext.facet', 'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri': 'https://anond.hatelabo.jp/20260326144026'}], 'index': {'byteEnd': 110, 'byteStart': 70}}], 'text': '新しい記事が投稿されました\n\n■\n金持ちを貧乏人...\nhttps://anond.hatelabo.jp/20260326144026'}, 'cid': 'bafyreihea3rzxa7lwv6bxwnq27g4ts2tsdf6nwzk6o5mq5iy3yx4u3ef2u'}}
# Received response: {'did': 'did:plc:ebmypgqpj5c443exofm6mrn4', 'time_us': 1774503709986877, 'kind': 'commit', 'commit': {'rev': '222223k4byv22', 'operation': 'create', 'collection': 'app.bsky.feed.post', 'rkey': '3mhwvfjcc2fh2', 'record': {'$type': 'app.bsky.feed.post', 'bridgyOriginalText': '<p>ほなら0.3.0をリリースさせてもろてね <a href="https://github.com/mohemohe/awayuki-desktop/releases/tag/v0.3.0" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">github.com/mohemohe/awayuki-de</span><span class="invisible">sktop/releases/tag/v0.3.0</span></a></p>', 'bridgyOriginalUrl': 'https://mstdn.plusminus.io/@mohemohe/116293874121471223', 'createdAt': '2026-03-26T05:41:34.000Z', 'embed': {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': 'Full Changelog: v0.2.0...v0.3.0', 'thumb': {'$type': 'blob', 'ref': {'$link': 'bafkreig4apim4zx4oa3uyl4n5kkxnlue7m7nlydeolkw22v3rntxndv3ey'}, 'mimeType': 'image/png', 'size': 84286}, 'title': 'Release Awayuki v0.3.0 · mohemohe/awayuki-desktop', 'uri': 'https://github.com/mohemohe/awayuki-desktop/releases/tag/v0.3.0'}}, 'facets': [{'$type': 'app.bsky.richtext.facet', 'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri': 'https://github.com/mohemohe/awayuki-desktop/releases/tag/v0.3.0'}], 'index': {'byteEnd': 114, 'byteStart': 51}}], 'langs': ['ja'], 'text': 'ほなら0.3.0をリリースさせてもろてね https://github.com/mohemohe/awayuki-desktop/releases/tag/v0.3.0'}, 'cid': 'bafyreidv76r3r7hvnz4ibcuf2ho53djyrjucwtwzfbetia4657ozgl27ti'}}

# %%
post_model = await stream_queue.get()

# %%
post_model.did
# Out:
# 'did:plc:n7yi3kpnye4e4iryocbrq6yt'

# %% [markdown]
# ### Testing out the Profile API

# %%
import requests

resp = requests.get('https://public.api.bsky.app/xrpc/app.bsky.actor.getProfile', params={'actor': post_model.did})
resp.json()
# Out:
# {'did': 'did:plc:n7yi3kpnye4e4iryocbrq6yt',
#  'handle': 'psychedelibear.bsky.social',
#  'displayName': 'Neurotic City',
#  'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:n7yi3kpnye4e4iryocbrq6yt/bafkreibudmbnv6m6jfz5mvivf2kjuc2be2az3ozjlcq7lyvi7k4qhp62wu',
#  'associated': {'lists': 0,
#   'feedgens': 0,
#   'starterPacks': 0,
#   'labeler': False,
#   'chat': {'allowIncoming': 'all'},
#   'activitySubscription': {'allowSubscriptions': 'followers'}},
#  'labels': [{'cid': 'bafyreigokqjijj46fwipsvvhdesntaypv7nxwgofmj7mydngvwqtrzfstq',
#    'cts': '2025-11-26T22:53:20.748Z',
#    'src': 'did:plc:ar7c4by46qjdydhdevvrndac',
#    'uri': 'at://did:plc:n7yi3kpnye4e4iryocbrq6yt/app.bsky.actor.profile/self',
#    'val': 'porn',
#    'ver': 1}],
#  'createdAt': '2023-12-18T23:47:01.606Z',
#  'description': 'AD account for a fat slutty bottom bear in Pittsburgh.',
#  'indexedAt': '2024-01-20T09:08:27.886Z',
#  'followersCount': 1593,
#  'followsCount': 1189,
#  'postsCount': 1891}
